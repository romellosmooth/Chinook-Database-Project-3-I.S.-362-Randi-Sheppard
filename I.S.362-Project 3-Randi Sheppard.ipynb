# %%
#Wanted to connect MySQL Workbench with Jupyter NoteBook#
pip install mysql-connector-python pandas notebook
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting mysql-connector-python
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/16.5 MB 11.2 MB/s eta 0:00:02
#    ------------- -------------------------- 5.5/16.5 MB 16.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.4/16.5 MB 17.8 MB/s eta 0:00:01
#    ------------------------------- -------- 13.1/16.5 MB 17.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 17.0 MB/s eta 0:00:00
# ...

# %%
#I downloaded the MySQL version of the Chinook database# 
#and  imported it into MySQL Workbench using the Chinook_MySql.sql script.#
#To verify the import, I ran:Select * FROM Customer LIMIT 5;#
#In the MySQL Workbench#

# %%
#Installing required Python Libraries in Juypter Notebook#
# !pip install pymysql

# %%
#Using SQLAlchemy and pymysql, I created a connection string to access the Chinook database#
from sqlalchemy import create_engine

username = 'root'       # e.g., 'root'
password = 'Iamthelight812!'       # e.g., 'Iamthelight812!'
host = '127.0.0.1'               # NOT '3306'
database = 'Chinook'

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}/{database}")

# %%
#I wrote a SQL query that joins five tables: Customer, Invoice, InvoiceLine, Track, and Album.#
import pandas as pd

query = """
SELECT 
    c.LastName,
    c.FirstName,
    t.Name AS TrackName,
    a.Title AS AlbumTitle
FROM Customer c
JOIN Invoice i ON c.CustomerId = i.CustomerId
JOIN InvoiceLine il ON i.InvoiceId = il.InvoiceId
JOIN Track t ON il.TrackId = t.TrackId
JOIN Album a ON t.AlbumId = a.AlbumId
ORDER BY c.LastName, c.FirstName;
"""

# Load into DataFrame
df = pd.read_sql(query, engine)
df.head()
# Out:
#   LastName FirstName                                          TrackName  \
# 0  Almeida   Roberto                            Right Next Door to Hell
# 1  Almeida   Roberto                                     In The Evening
# 2  Almeida   Roberto                                   Fool In The Rain
# 3  Almeida   Roberto  Saudade Dos Aviões Da Panair (Conversando No Bar)
# 4  Almeida   Roberto                             Caso Você Queira Saber
#
#                 AlbumTitle
# 0      Use Your Illusion I
# 1  In Through The Out Door
# 2  In Through The Out Door
# 3                    Minas
# 4                    Minas

# %%
#The query results were loaded into a pandas DataFrame. Here's a preview of the first five rows: Above#

# %%
#Conclusion:#
#Import a relational database into MySQL#

#Write a multi-table SQL join#

#Connect MySQL to Jupyter Notebook using Python#

#Load and display query results in pandas#
